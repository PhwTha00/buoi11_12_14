# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.

# %%
data = {
    'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70],
    'sex': ['M', 'F', 'F', 'M', 'F']
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age  preTestScore  postTestScore sex
# 0  Jason   42             4             25   M
# 1  Molly   52            24             94   F
# 2   Tina   36            31             57   F
# 3   Jake   24             2             62   M
# 4    Amy   73             3             70   F

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age'], alpha=0.5)
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatterplot of preTestScore and postTestScore (Size by Age)')
plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['postTestScore']*4.5, c=pd.factorize(df['sex'])[0], alpha=0.5)
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatterplot of preTestScore and postTestScore (Size by 4.5 times postTestScore, Color by Sex)')
plt.colorbar(label='Sex')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
#Question: Is there a correlation between preTestScore and postTestScore?
correlation = df['preTestScore'].corr(df['postTestScore'])
print("Correlation coefficient between preTestScore and postTestScore:", correlation)
# Out:
# Correlation coefficient between preTestScore and postTestScore: 0.37803911777651406
